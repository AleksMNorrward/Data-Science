# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# The dataset can be found on Kaggle, this one is
#
# [Online Payment Fraus Detection Dataset](https://www.kaggle.com/datasets/jainilcoder/online-payment-fraud-detection)

# %%
data = pd.read_csv("/content/onlinefraud.csv")
data.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0      0.0             0.0
# 1  M2044282225             0.0             0.0      0.0             0.0
# 2   C553264065             0.0             0.0      1.0             0.0
# 3    C38997010         21182.0             0.0      1.0             0.0
# 4  M1230701703             0.0             0.0      0.0             0.0

# %%
data.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  2.399371e+06  2.399371e+06   2.399371e+06    2.399371e+06
# mean   1.016200e+02  1.592562e+05   8.503296e+05    8.717237e+05
# std    6.853654e+01  2.668586e+05   2.920055e+06    2.956353e+06
# min    1.000000e+00  2.000000e-02   0.000000e+00    0.000000e+00
# 25%    3.300000e+01  1.274056e+04   0.000000e+00    0.000000e+00
# 50%    1.330000e+02  7.730541e+04   1.488100e+04    0.000000e+00
# 75%    1.620000e+02  2.143226e+05   1.175498e+05    1.585621e+05
# max    2.010000e+02  1.000000e+07   3.893942e+07    3.894623e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    2.399370e+06    2.399370e+06  2.399370e+06       2399370.0
# mean     9.953152e+05    1.108070e+06  9.427475e-04             0.0
# std      2.302244e+06    2.389992e+06  3.068972e-02             0.0
# min      0.000000e+00    0.000000e+00  0.000000e+00             0.0
# ...

# %%
data.isna().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          1
# oldbalanceDest    1
# newbalanceDest    1
# isFraud           1
# isFlaggedFraud    1
# dtype: int64

# %%
data.shape
# Out:
# (2399371, 11)

# %%
data["type"].unique() #Helps to see what values can variable hage in this column
# Out:
# array(['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT', 'CASH_IN'],
#       dtype=object)

# %%
type = data["type"].value_counts() #helps to see how many times in sum one value is in the column
#For example, there are 83963 rows that ave value of "type" variable PAYMENT
transactions_names = type.index
transactions_sum_values = type.values
type
# Out:
# CASH_OUT    853290
# PAYMENT     803492
# CASH_IN     527823
# TRANSFER    198968
# DEBIT        15798
# Name: type, dtype: int64

# %%
import plotly.express as px

# %%
px.pie(data,
       values=transactions_sum_values,
       names= transactions_names,
       hole = 0.1,
       title = "Distribution of Transaction Types")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#data = data.fillna(data.mean(), inplace = True)
data = data.dropna()
data
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT    9839.64  C1231006815      170136.00
# 1           1   PAYMENT    1864.28  C1666544295       21249.00
# 2           1  TRANSFER     181.00  C1305486145         181.00
# 3           1  CASH_OUT     181.00   C840083671         181.00
# 4           1   PAYMENT   11668.14  C2048537720       41554.00
# ...       ...       ...        ...          ...            ...
# 2399365   201   PAYMENT    3841.65  C1878176239        3056.00
# 2399366   201   PAYMENT     883.53  C1808530911        6059.00
# 2399367   201  TRANSFER  293885.59  C1685785465       11151.00
# 2399368   201   PAYMENT    2977.22  C1671700217       49635.00
# 2399369   201   PAYMENT   19296.84   C743873693       46657.78
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155             0.0            0.00      0.0
# ...

# %%
data.replace(to_replace = ['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT', 'CASH_IN'],
                    value = [1, 2, 3, 4, 5], inplace = True)
data
# Out:
#          step  type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1     1    9839.64  C1231006815      170136.00       160296.36
# 1           1     1    1864.28  C1666544295       21249.00        19384.72
# 2           1     2     181.00  C1305486145         181.00            0.00
# 3           1     3     181.00   C840083671         181.00            0.00
# 4           1     1   11668.14  C2048537720       41554.00        29885.86
# ...       ...   ...        ...          ...            ...             ...
# 2399365   201     1    3841.65  C1878176239        3056.00            0.00
# 2399366   201     1     883.53  C1808530911        6059.00         5175.47
# 2399367   201     2  293885.59  C1685785465       11151.00            0.00
# 2399368   201     1    2977.22  C1671700217       49635.00        46657.78
# 2399369   201     1   19296.84   C743873693       46657.78        27360.94
#
# ...

# %%
y = data["isFraud"]
y
# Out:
# 0          0.0
# 1          0.0
# 2          1.0
# 3          1.0
# 4          0.0
#           ...
# 2399365    0.0
# 2399366    0.0
# 2399367    0.0
# 2399368    0.0
# 2399369    0.0
# Name: isFraud, Length: 2399370, dtype: float64

# %%
X = data[['type', 'amount', 'oldbalanceOrg', 'newbalanceOrig']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state= 42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy of classification: ", model.score(X_test, y_test))
# Out:
# Accuracy of classification:  0.9996499081008765

# %%
model.predict([[2,9800,170136,160296]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# array([0.])
